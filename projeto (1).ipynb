# %%
import ipywidgets as widgets
from IPython.display import display
from ipywidgets import interact
import pandas as pd
import psycopg2 as pg
import sqlalchemy
from sqlalchemy import create_engine
import panel as pn
from sqlalchemy import insert

# %%
con = pg.connect(host='localhost', dbname= 'nutrigest', user='postgres', password= 'toin')

# %%
cnx = 'postgresql://postgres:postgres@localhost:5432/nutrigest'
sqlalchemy.create_engine(cnx)
# Out:
# Engine(postgresql://postgres:***@localhost:5432/nutrigest)

# %%
#campos de texto

#declare esta variável para usar na consulta de campos em branco
flag=''

nome = widgets.Text(
    value='',
    placeholder='Digite o nome',
    description='Nome: ',
    disabled=False
)


sobrenome = widgets.Text(
    value='',
    placeholder='Digite o sobrenome',
    description='sobrenome: ',
    disabled=False
)

cartao = widgets.Text(
    value='',
    placeholder='Digite o cartao',
    description='cartao: ',
    disabled=False
)

id = widgets.Text(
    value='',
    placeholder='Digite o ID',
    description='ID: ',
    disabled=False
)

nome_pesq = widgets.Text(
    value='',
    placeholder='Digite o nome para pesquisar',
    description='Nome: ',
    disabled=False
)

button = widgets.Button(description="Inserir", value='')
button2 = widgets.Button(description="Consultar nome", value='Preencha o nome para consultar')
button3 = widgets.Button(description="Deletar", value='Preencha o ID para deletar')


# ação que vai ser executada ao clicar no botão
# inserir
def on_button_clicked_insert(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("insert into usuario(nome, sobrenome, cartao) VALUES (%s, %s, %s)", 
                    (nome.value, sobrenome.value, cartao.value))
        cursor.query
        con.commit()
        
        display("Cadastrado com sucesso.")
        display(nome, sobrenome, cartao, button, button2, button3,df)

    except:
        cursor.execute("ROLLBACK")
        #output.clear_output()        
        display(nome, sobrenome, cartao, button, button2, button3)
        display("Não foi possível realizar a inserção. Verifique restrições.")
        
    finally:
        cursor.close()
        
        # inserir
def on_button_clicked_delete(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("delete from usuario where id=%s", (id.value,))
        rows_deleted = cursor.rowcount
        con.commit()
        df = pd.read_sql("select * from usuario", cnx)
        #output.clear_output()        
        display(nome, sobrenome, cartao, button, button2, button3,df)
    except:
        cursor.execute("ROLLBACK")
        #output.clear_output()        
        display(nome, sobrenome, cartao, button, button2, button3)
        display("Não foi possível realizar deletar. Verifique restrições.")
            
    finally:
        cursor.close()
        
# consultar        
# neste exemplo o método de consulta usa o dataframe do pandas como retorno. Note que a flag é usada para ignorar quando um 
# campo for null (condição é sempre verdadeira). Veja que para cpf, que é uma string, foi usado '{cpf.value})' como parametro
# e para dnr que é numérico, foi usado {dnr.value} (sem aspas simples).
def on_button_clicked_query(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("select * from usuario where nome = %s  or nome = %s", 
                    (nome_pesq.value,flag,))
        rows = cursor.fetchall()
        #df = pd.read_sql_query(query, cnx)
        with output:
            output.clear_output()   
            display(nome, sobrenome, cartao, button, nome_pesq, button2, id, button3)
            for row in rows:
                display(row)
        output
    except psycopg2.OperationalError as e:
        logging.error(str(e))
        output.clear_output()
        output.display(nome, sobrenome, cartao, button, button2, button3)
        output.display("Não foi possível realizar a consulta. ")


# definição que determinado botão vai executar a ação

# botão de inserir 
button.on_click(on_button_clicked_insert)
#botão de consultar
button2.on_click(on_button_clicked_query)
# deletar
button3.on_click(on_button_clicked_delete)

#saída da tela
output = widgets.Output()


    
with output:
    output.clear_output()   
    display(nome, sobrenome, cartao, button, nome_pesq, button2, id, button3)
    
output
# Out:
# Output()

# %%
#campos de texto

#declare esta variável para usar na consulta de campos em branco
flag=''

nome_alimento = widgets.Text(
    value='',
    placeholder='Digite o nome do alimento',
    description='Nome: ',
    disabled=False
)


glutem = widgets.Text(
    value='',
    placeholder='Tem glutem?',
    description='Tem glutem?: ',
    disabled=False
)

lactose = widgets.Text(
    value='',
    placeholder='Tem lactose?',
    description='Tem lactose? ',
    disabled=False
)

tipo = widgets.Text(
    value='',
    placeholder='Qual o tipo',
    description='Tipo: ',
    disabled=False
)

id_alimento = widgets.Text(
    value='',
    placeholder='Digite o id para deletar',
    description='ID: ',
    disabled=False
)

nome_pesq = widgets.Text(
    value='',
    placeholder='Digite o nome para pesquisar',
    description='Nome: ',
    disabled=False
)

button = widgets.Button(description="Inserir", value='')
button2 = widgets.Button(description="Consultar alimento", value='Preencha o alimento para consultar')
button3 = widgets.Button(description="Deletar", value='Preencha o ID para deletar')


# ação que vai ser executada ao clicar no botão
# inserir
def on_button_clicked_insert(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("insert into alimento(nome_alimento, glutem, lactose, tipo) VALUES (%s, %s, %s, %s)", 
                    (nome_alimento.value, glutem.value, lactose.value, tipo.value))
        cursor.query
        con.commit()
        
        display("Cadastrado com sucesso.")
        display(nome_alimento, glutem, lactose, tipo, button, button2, button3,df)

    except:
        cursor.execute("ROLLBACK")
        #output.clear_output()        
        display(nome_alimento, glutem, lactose, tipo, button, button2, button3)
        display("Não foi possível realizar a inserção. Verifique restrições.")
        
    finally:
        cursor.close()
        
        # inserir
def on_button_clicked_delete(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("delete from alimento where id_alimento=%s", (id_alimento.value,))
        rows_deleted = cursor.rowcount
        con.commit()
        df = pd.read_sql("select * from alimento", cnx)
        #output.clear_output()        
        display(nome_alimento, glutem, lactose, tipo, button, button2, button3,df)
    except:
        cursor.execute("ROLLBACK")
        #output.clear_output()        
        display(nome_alimento, glutem, lactose, tipo, button, button2, button3)
        display("Não foi possível realizar deletar. Verifique restrições.")
            
    finally:
        cursor.close()
        
# consultar        
# neste exemplo o método de consulta usa o dataframe do pandas como retorno. Note que a flag é usada para ignorar quando um 
# campo for null (condição é sempre verdadeira). Veja que para cpf, que é uma string, foi usado '{cpf.value})' como parametro
# e para dnr que é numérico, foi usado {dnr.value} (sem aspas simples).
def on_button_clicked_query(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("select * from alimento where nome_alimento = %s  or nome_alimento = %s", 
                    (nome_pesq.value,flag,))
        rows = cursor.fetchall()
        #df = pd.read_sql_query(query, cnx)
        with output:
            output.clear_output()   
            display(nome_alimento, glutem, lactose, tipo, button, nome_pesq, button2, id_alimento, button3)
            for row in rows:
                display(row)
        output
    except:
        #output.clear_output()        
        display(nome_alimento, glutem, lactose, tipo, button, button2, button3)
        display("Não foi possível realizar a consulta. ")


# definição que determinado botão vai executar a ação

# botão de inserir 
button.on_click(on_button_clicked_insert)
#botão de consultar
button2.on_click(on_button_clicked_query)
# deletar
button3.on_click(on_button_clicked_delete)

#saída da tela
output = widgets.Output()


    
with output:
    #output.clear_output()   
    display(nome_alimento, glutem, lactose, tipo, button, nome_pesq, button2, id_alimento, button3)
    
output
# Out:
# Output()

# %%
#campos de texto

#declare esta variável para usar na consulta de campos em branco
flag=''

nome_ingrediente = widgets.Text(
    value='',
    placeholder='Digite o nome do ingrediente',
    description='Nome: ',
    disabled=False
)


glutem = widgets.Text(
    value='',
    placeholder='Tem glutem?',
    description='Tem glutem?: ',
    disabled=False
)

lactose = widgets.Text(
    value='',
    placeholder='Tem lactose?',
    description='Tem lactose? ',
    disabled=False
)

id_ingrediente = widgets.Text(
    value='',
    placeholder='Digite o id para deletar',
    description='ID: ',
    disabled=False
)

nome_pesq = widgets.Text(
    value='',
    placeholder='Digite o nome para pesquisar',
    description='Nome: ',
    disabled=False
)

button = widgets.Button(description="Inserir", value='')
button2 = widgets.Button(description="Consultar ingrediente", value='Preencha o ingrediente para consultar')
button3 = widgets.Button(description="Deletar", value='Preencha o ID para deletar')


# ação que vai ser executada ao clicar no botão
# inserir
def on_button_clicked_insert(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("insert into ingrediente(nome, glutem, lactose) VALUES (%s, %s, %s)", 
                    (nome_ingrediente.value, glutem.value, lactose.value))
        cursor.query
        con.commit()
        
        display("Cadastrado com sucesso.")
        display(nome_ingrediente, glutem, lactose, button, button2, button3,df)

    except:
        cursor.execute("ROLLBACK")
        #output.clear_output()        
        display(nome_alimento, glutem, lactose, button, button2, button3)
        display("Não foi possível realizar a inserção. Verifique restrições.")
        
    finally:
        cursor.close()
        
        # inserir
def on_button_clicked_delete(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("delete from ingrediente where id_ingrediente=%s", (id_ingrediente.value,))
        rows_deleted = cursor.rowcount
        con.commit()
        df = pd.read_sql("select * from ingrediente", cnx)
        #output.clear_output()        
        display(nome_ingrediente, glutem, lactose, button, button2, button3,df)
    except:
        cursor.execute("ROLLBACK")
        #output.clear_output()        
        display(nome_alimento, glutem, lactose, button, button2, button3)
        display("Não foi possível realizar deletar. Verifique restrições.")
            
    finally:
        cursor.close()
        
# consultar        
# neste exemplo o método de consulta usa o dataframe do pandas como retorno. Note que a flag é usada para ignorar quando um 
# campo for null (condição é sempre verdadeira). Veja que para cpf, que é uma string, foi usado '{cpf.value})' como parametro
# e para dnr que é numérico, foi usado {dnr.value} (sem aspas simples).
def on_button_clicked_query(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("select * from ingrediente where nome = %s  or nome = %s", 
                    (nome_pesq.value,flag,))
        rows = cursor.fetchall()
        #df = pd.read_sql_query(query, cnx)
        with output:
            output.clear_output()   
            display(nome_ingrediente, glutem, lactose, button, nome_pesq, button2, id_ingrediente, button3, row)#, sobrenome, cartao, button, button2, button3,df)
        output
    except:
        #output.clear_output()        
        display(nome_ingrediente, glutem, lactose, button, button2, button3)
        display("Não foi possível realizar a consulta. ")


# definição que determinado botão vai executar a ação

# botão de inserir 
button.on_click(on_button_clicked_insert)
#botão de consultar
button2.on_click(on_button_clicked_query)
# deletar
button3.on_click(on_button_clicked_delete)

#saída da tela
output = widgets.Output()


    
with output:
    #output.clear_output()   
    display(nome_ingrediente, glutem, lactose, button, nome_pesq, button2, id_ingrediente, button3)
    
output
# Out:
# Output()

# %%
#campos de texto

#declare esta variável para usar na consulta de campos em branco
flag=''

nome_suco = widgets.Text(
    value='',
    placeholder='Digite o nome do suco',
    description='Nome: ',
    disabled=False
)


descricao = widgets.Text(
    value='',
    placeholder='descricao',
    description='descricao: ',
    disabled=False
)

sabor = widgets.Text(
    value='',
    placeholder='sabor',
    description='sabor ',
    disabled=False
)

acucar = widgets.Text(
    value='',
    placeholder='Tem acucar?',
    description='Tem acucar? ',
    disabled=False
)

id_suco = widgets.Text(
    value='',
    placeholder='Digite o id para deletar',
    description='ID: ',
    disabled=False
)

nome_pesq = widgets.Text(
    value='',
    placeholder='Digite o suco para pesquisar',
    description='Nome: ',
    disabled=False
)

button = widgets.Button(description="Inserir", value='')
button2 = widgets.Button(description="Consultar alimento", value='Preencha o suco para consultar')
button3 = widgets.Button(description="Deletar", value='Preencha o ID para deletar')


# ação que vai ser executada ao clicar no botão
# inserir
def on_button_clicked_insert(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("insert into suco(nome, descricao, sabor, acucar) VALUES (%s, %s, %s, %s)", 
                    (nome_suco.value, descricao.value, sabor.value, acucar.value))
        cursor.query
        con.commit()
        
        display("Cadastrado com sucesso.")
        display(nome_suco, descricao, sabor, acucar, button, button2, button3,df)

    except:
        cursor.execute("ROLLBACK")
        #output.clear_output()        
        display(nome_suco, descricao, sabor, acucar, button, button2, button3)
        display("Não foi possível realizar a inserção. Verifique restrições.")
        
    finally:
        cursor.close()
        
        # inserir
def on_button_clicked_delete(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("delete from suco where id_suco=%s", (id_suco.value,))
        rows_deleted = cursor.rowcount
        con.commit()
        df = pd.read_sql("select * from suco", cnx)
        #output.clear_output()        
        display(nome_suco, descricao, sabor, acucar, button, button2, button3,df)
    except:
        cursor.execute("ROLLBACK")
        #output.clear_output()        
        display(nome_suco, descricao, sabor, acucar, button, button2, button3)
        display("Não foi possível realizar deletar. Verifique restrições.")
            
    finally:
        cursor.close()
        
# consultar        
# neste exemplo o método de consulta usa o dataframe do pandas como retorno. Note que a flag é usada para ignorar quando um 
# campo for null (condição é sempre verdadeira). Veja que para cpf, que é uma string, foi usado '{cpf.value})' como parametro
# e para dnr que é numérico, foi usado {dnr.value} (sem aspas simples).
def on_button_clicked_query(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("select * from suco where nome = %s  or nome = %s", 
                    (nome_pesq.value,flag,))
        rows = cursor.fetchall()
        #df = pd.read_sql_query(query, cnx)
        with output:
            output.clear_output()   
            display(nome_suco, descricao, sabor, acucar, button, nome_pesq, button2, id_suco, button3)
            for row in rows:
                display(row)
        output
    except:
        #output.clear_output()        
        display(nome_suco, descricao, sabor, acucar, button, button2, button3)
        display("Não foi possível realizar a consulta. ")


# definição que determinado botão vai executar a ação

# botão de inserir 
button.on_click(on_button_clicked_insert)
#botão de consultar
button2.on_click(on_button_clicked_query)
# deletar
button3.on_click(on_button_clicked_delete)

#saída da tela
output = widgets.Output()


    
with output:
    #output.clear_output()   
    display(nome_suco, descricao, sabor, acucar, button, nome_pesq, button2, id_suco, button3)
    
output
# Out:
# Output()

# %%
#campos de texto

#declare esta variável para usar na consulta de campos em branco
flag=''

nome_sobremesa = widgets.Text(
    value='',
    placeholder='Digite o nome do sobremesa',
    description='Nome: ',
    disabled=False
)


tipo = widgets.Text(
    value='',
    placeholder='tipo',
    description='tipo: ',
    disabled=False
)

id_sobremesa = widgets.Text(
    value='',
    placeholder='Digite o id para deletar',
    description='ID: ',
    disabled=False
)

nome_pesq = widgets.Text(
    value='',
    placeholder='Digite o suco para pesquisar',
    description='Nome: ',
    disabled=False
)

button = widgets.Button(description="Inserir", value='')
button2 = widgets.Button(description="Consultar sobremesa", value='Preencha a sobremesa para consultar')
button3 = widgets.Button(description="Deletar", value='Preencha o ID para deletar')


# ação que vai ser executada ao clicar no botão
# inserir
def on_button_clicked_insert(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("insert into sobremesa(nome, tipo) VALUES (%s, %s)", 
                    (nome_sobremesa.value, tipo.value))
        cursor.query
        con.commit()
        
        display("Cadastrado com sucesso.")
        display(nome_sobremesa, tipo, button, button2, button3,df)

    except:
        cursor.execute("ROLLBACK")
        #output.clear_output()        
        display(nome_sobremesa, tipo, button, button2, button3)
        display("Não foi possível realizar a inserção. Verifique restrições.")
        
    finally:
        cursor.close()
        
        # inserir
def on_button_clicked_delete(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("delete from sobremesa where id_sobremesa=%s", (id_sobremesa.value,))
        rows_deleted = cursor.rowcount
        con.commit()
        df = pd.read_sql("select * from sobremesa", cnx)
        #output.clear_output()        
        display(nome_sobremesa, tipo, button, button2, button3,df)
    except:
        cursor.execute("ROLLBACK")
        #output.clear_output()        
        display(nome_sobremesa, tipo, button, button2, button3)
        display("Não foi possível realizar deletar. Verifique restrições.")
            
    finally:
        cursor.close()
        
# consultar        
# neste exemplo o método de consulta usa o dataframe do pandas como retorno. Note que a flag é usada para ignorar quando um 
# campo for null (condição é sempre verdadeira). Veja que para cpf, que é uma string, foi usado '{cpf.value})' como parametro
# e para dnr que é numérico, foi usado {dnr.value} (sem aspas simples).
def on_button_clicked_query(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("select * from sobremesa where nome = %s  or nome = %s", 
                    (nome_pesq.value,flag,))
        rows = cursor.fetchall()
        #df = pd.read_sql_query(query, cnx)
        with output:
            output.clear_output()   
            display(nome_sobremesa, tipo, button, nome_pesq, button2, id_sobremesa, button3)
            for row in rows:
                display(row)
        output
    except:
        #output.clear_output()        
        display(nome_sobremesa, tipo, button, button2, button3)
        display("Não foi possível realizar a consulta. ")


# definição que determinado botão vai executar a ação

# botão de inserir 
button.on_click(on_button_clicked_insert)
#botão de consultar
button2.on_click(on_button_clicked_query)
# deletar
button3.on_click(on_button_clicked_delete)

#saída da tela
output = widgets.Output()


    
with output:
    #output.clear_output()   
    display(nome_sobremesa, tipo, button, nome_pesq, button2, id_sobremesa, button3)
    
output
# Out:
# Output()

# %%
#campos de texto

#declare esta variável para usar na consulta de campos em branco
flag=''

nome_refeicao = widgets.Text(
    value='',
    placeholder='Digite o nome da refeicao',
    description='Nome: ',
    disabled=False
)


descricao = widgets.Text(
    value='',
    placeholder='descricao',
    description='descricao: ',
    disabled=False
)

idSuco = widgets.Text(
    value='',
    placeholder='idSuco',
    description='idSuco: ',
    disabled=False
)

idSobremesa = widgets.Text(
    value='',
    placeholder='idSobremesa',
    description='idSobremesa: ',
    disabled=False
)

id_refeicao = widgets.Text(
    value='',
    placeholder='Digite o id da refeicao para deletar',
    description='ID: ',
    disabled=False
)

nome_pesq = widgets.Text(
    value='',
    placeholder='Digite o suco para pesquisar',
    description='Nome: ',
    disabled=False
)

button = widgets.Button(description="Inserir", value='')
button2 = widgets.Button(description="Consultar sobremesa", value='Preencha a refeicao para consultar')
button3 = widgets.Button(description="Deletar", value='Preencha o ID para deletar')


# ação que vai ser executada ao clicar no botão
# inserir
def on_button_clicked_insert(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("insert into refeicao(nome, descricao, id_suco, id_sobremesa) VALUES (%s, %s, %s, %s)", 
                    (nome_refeicao.value, descricao.value, idSuco.value, idSobremesa.value))
        cursor.query
        con.commit()
        
        display("Cadastrado com sucesso.")
        display(nome_refeicao, descricao, idSuco, idSobremesa, button, button2, button3,df)

    except:
        cursor.execute("ROLLBACK")
        #output.clear_output()        
        display(nome_refeicao, descricao, idSuco, idSobremesa, button, button2, button3)
        display("Não foi possível realizar a inserção. Verifique restrições.")
        
    finally:
        cursor.close()
        
        # inserir
def on_button_clicked_delete(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("delete from refeicao where id_refeicao=%s", (id_refeicao.value,))
        rows_deleted = cursor.rowcount
        con.commit()
        df = pd.read_sql("select * from refeicao", cnx)
        #output.clear_output()        
        display(nome_refeicao, descricao, idSuco, idSobremesa, button, button2, button3,df)
    except:
        cursor.execute("ROLLBACK")
        #output.clear_output()        
        display(nome_refeicao, descricao, idSuco, idSobremesa, button, button2, button3)
        display("Não foi possível realizar deletar. Verifique restrições.")
            
    finally:
        cursor.close()
        
# consultar        
# neste exemplo o método de consulta usa o dataframe do pandas como retorno. Note que a flag é usada para ignorar quando um 
# campo for null (condição é sempre verdadeira). Veja que para cpf, que é uma string, foi usado '{cpf.value})' como parametro
# e para dnr que é numérico, foi usado {dnr.value} (sem aspas simples).
def on_button_clicked_query(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("select * from refeicao where nome = %s  or nome = %s", 
                    (nome_pesq.value,flag,))
        rows = cursor.fetchall()
        #df = pd.read_sql_query(query, cnx)
        with output:
            output.clear_output()   
            display(nome_refeicao, descricao, idSuco, idSobremesa, button, nome_pesq, button2, id_refeicao, button3)
            for row in rows:
                display(row)
        output
    except:
        #output.clear_output()        
        display(nome_refeicao, descricao, idSuco, idSobremesa, button, button2, button3)
        display("Não foi possível realizar a consulta. ")


# definição que determinado botão vai executar a ação

# botão de inserir 
button.on_click(on_button_clicked_insert)
#botão de consultar
button2.on_click(on_button_clicked_query)
# deletar
button3.on_click(on_button_clicked_delete)

#saída da tela
output = widgets.Output()


    
with output:
    #output.clear_output()   
    display(nome_refeicao, descricao, idSuco, idSobremesa, button, nome_pesq, button2, id_refeicao, button3)
    
output
# Out:
# Output()

# %%
#campos de texto

#declare esta variável para usar na consulta de campos em branco
flag=''

nome_refeicao = widgets.Text(
    value='',
    placeholder='Digite o nome da refeicao',
    description='Nome: ',
    disabled=False
)


descricao = widgets.Text(
    value='',
    placeholder='descricao',
    description='descricao: ',
    disabled=False
)

idSuco = widgets.Text(
    value='',
    placeholder='idSuco',
    description='idSuco: ',
    disabled=False
)

idSobremesa = widgets.Text(
    value='',
    placeholder='idSobremesa',
    description='idSobremesa: ',
    disabled=False
)

id_refeicao = widgets.Text(
    value='',
    placeholder='Digite o id da refeicao para deletar',
    description='ID: ',
    disabled=False
)

nome_pesq = widgets.Text(
    value='',
    placeholder='Digite o suco para pesquisar',
    description='Nome: ',
    disabled=False
)

button = widgets.Button(description="buscar", value='')
button2 = widgets.Button(description="buscar", value='')
button3 = widgets.Button(description="buscar", value='')


# ação que vai ser executada ao clicar no botão
# inserir
def on_button_clicked_insert(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("select * from refeicoes_com_glutem_lactose")
        rows = cursor.fetchall()
        #df = pd.read_sql_query(query, cnx)
        with output:
            output.clear_output()   
            display("listar as refeições e informar se tem glutem ou lactose", button, "listar a quantidade de proteina de cada refeição" , button2,"listar os ingredientes de cada refeição", button3)
            for row in rows:
                display(row)
        output

    except:
        cursor.execute("ROLLBACK")
        #output.clear_output()        
        display(nome_refeicao, descricao, idSuco, idSobremesa, button, button2, button3)
        display("Não foi possível realizar a inserção. Verifique restrições.")
        
    finally:
        cursor.close()
        
        # inserir
def on_button_clicked_delete(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("select * from alimentos_com_ingredientes")
        rows = cursor.fetchall()
        #df = pd.read_sql_query(query, cnx)
        with output:
            output.clear_output()   
            display("listar as refeições e informar se tem glutem ou lactose", button, "listar a quantidade de proteina de cada refeição" , button2,"listar o suco de cada refeição", button3)
            for row in rows:
                display(row)
        output
    except:
        cursor.execute("ROLLBACK")
        #output.clear_output()        
        display(nome_refeicao, descricao, idSuco, idSobremesa, button, button2, button3)
        display("Não foi possível realizar deletar. Verifique restrições.")
            
    finally:
        cursor.close()
        
# consultar        
# neste exemplo o método de consulta usa o dataframe do pandas como retorno. Note que a flag é usada para ignorar quando um 
# campo for null (condição é sempre verdadeira). Veja que para cpf, que é uma string, foi usado '{cpf.value})' como parametro
# e para dnr que é numérico, foi usado {dnr.value} (sem aspas simples).
def on_button_clicked_query(b):
    try:
        cursor= con.cursor()
        cursor.execute("SET search_path TO 'projetoFinal';")
        cursor.execute("select * from proteinas_por_alimento")
        rows = cursor.fetchall()
        #df = pd.read_sql_query(query, cnx)
        with output:
            output.clear_output()   
            display("listar as refeições e informar se tem glutem ou lactose", button, "listar a quantidade de proteina de cada refeição" , button2,"listar o suco de cada refeição", button3)
            for row in rows:
                display(row)
        output
    except:
        #output.clear_output()        
        display(nome_refeicao, descricao, idSuco, idSobremesa, button, button2, button3)
        display("Não foi possível realizar a consulta. ")


# definição que determinado botão vai executar a ação

# botão de inserir 
button.on_click(on_button_clicked_insert)
#botão de consultar
button2.on_click(on_button_clicked_query)
# deletar
button3.on_click(on_button_clicked_delete)

#saída da tela
output = widgets.Output()


    
with output:
    #output.clear_output()   
    display("listar as refeições e informar se tem glutem ou lactose", button, "listar a quantidade de proteina de cada refeição" , button2,"listar o suco de cada refeição", button3)
    
output
# Out:
# Output()
